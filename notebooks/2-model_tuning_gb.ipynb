# %% [markdown]
# # Gradient Boosting Model training and tuning

# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold, cross_val_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report
from sklearn.utils.class_weight import compute_class_weight
from imblearn.combine import SMOTEENN
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import PolynomialFeatures
from scipy.stats import randint
import numpy as np
import joblib

# %% [markdown]
# ## Load preprocessed subset of Selects data

# %%
# Load the Selects subset
data_path = "../data/subset_selected_parties_model.csv"
df = pd.read_csv(data_path)

# %% [markdown]
# ## Model tuning and training

# %%
# Extract features and target
X = df.drop(['vdn1b'], axis=1)
y = df['vdn1b']

# %%
# Store original feature names
original_feature_names = X.columns.tolist()

# Polynomial Features
poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
X_poly = poly.fit_transform(X)

# Get polynomial feature names
poly_feature_names = poly.get_feature_names_out(original_feature_names)

# Interaction Feature: Age * Income
X_poly_interaction = np.hstack([X_poly, (X['age'].values * X['income'].values).reshape(-1, 1)])

# Create final feature names list
final_feature_names = poly_feature_names.tolist() + ['age_income_interaction']

# %%
# Combine SMOTE and ENN for oversampling and cleaning
smote_enn = SMOTEENN(random_state=42)
X_resampled, y_resampled = smote_enn.fit_resample(X_poly_interaction, y)

# Further handle any class imbalance with random undersampling
undersample = RandomUnderSampler(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = undersample.fit_resample(X_resampled, y_resampled)

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
# Define the parameter grid for hyperparameter tuning
param_dist = {
    'n_estimators': randint(100, 500),
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'max_depth': [3, 5, 10, 20],
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 20),
    'max_features': ['sqrt', 'log2']
}

# Initialize the model
gb_model = GradientBoostingClassifier(random_state=42)

# Initialize RandomizedSearchCV with StratifiedKFold
stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
random_search = RandomizedSearchCV(estimator=gb_model, param_distributions=param_dist, n_iter=100, cv=stratified_kfold, n_jobs=-1, random_state=42, verbose=2)

# Fit the model
random_search.fit(X_train, y_train)

# Get the best parameters
best_params = random_search.best_params_
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=19, min_samples_split=12, n_estimators=187; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=19, min_samples_split=12, n_estimators=187; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=19, min_samples_split=12, n_estimators=187; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=19, min_samples_split=12, n_estimators=187; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=19, min_samples_split=12, n_estimators=187; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=20, max_features=sqrt, min_samples_leaf=15, min_samples_split=12, n_estimators=171; total time=   8.3s
# [CV] END learning_rate=0.1, max_depth=20, max_features=sqrt, min_samples_leaf=15, min_samples_split=12, n_estimators=171; total time=   8.4s
# [CV] END learning_rate=0.1, max_depth=20, max_features=sqrt, min_samples_leaf=15, min_samples_split=12, n_estimators=171; total time=   8.4s
# [CV] END learning_rate=0.1, max_depth=20, max_features=sqrt, min_samples_leaf=15, min_samples_split=12, n_estimators=171; total time=   8.5s
# [CV] END learning_rate=0.1, max_depth=20, max_features=sqrt, min_samples_leaf=15, min_samples_split=12, n_estimators=171; total time=   8.5s
# [CV] END learning_rate=0.2, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=413; total time=   7.0s
# [CV] END learning_rate=0.2, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=413; total time=   7.1s
# [CV] END learning_rate=0.2, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=413; total time=   7.2s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=17, min_samples_split=11, n_estimators=287; total time=   4.7s
# [CV] END learning_rate=0.2, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=413; total time=   7.6s
# [CV] END learning_rate=0.2, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=413; total time=   7.6s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=17, min_samples_split=11, n_estimators=287; total time=   4.5s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=17, min_samples_split=11, n_estimators=287; total time=   4.3s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=17, min_samples_split=11, n_estimators=287; total time=   4.3s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=17, min_samples_split=11, n_estimators=287; total time=   4.3s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=13, n_estimators=154; total time=   5.9s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=13, n_estimators=154; total time=   5.8s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=13, n_estimators=154; total time=   5.8s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=13, n_estimators=154; total time=   5.7s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=13, n_estimators=154; total time=   5.8s
# [CV] END learning_rate=0.2, max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=406; total time=   9.6s
# [CV] END learning_rate=0.2, max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=406; total time=   9.7s
# [CV] END learning_rate=0.2, max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=406; total time=   9.8s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=443; total time=  51.0s
# [CV] END learning_rate=0.2, max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=406; total time=  10.0s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=443; total time=  51.1s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=443; total time=  51.3s
# [CV] END learning_rate=0.2, max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=406; total time=   9.7s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=19, n_estimators=487; total time=   9.8s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=443; total time=  50.9s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=3, n_estimators=443; total time=  51.7s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=19, n_estimators=487; total time=   9.7s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=19, n_estimators=487; total time=   9.7s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=19, n_estimators=487; total time=  10.7s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=19, n_estimators=487; total time=  10.9s
# [CV] END learning_rate=0.01, max_depth=5, max_features=log2, min_samples_leaf=15, min_samples_split=8, n_estimators=363; total time=   9.8s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=18, min_samples_split=10, n_estimators=445; total time=  16.5s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=18, min_samples_split=10, n_estimators=445; total time=  16.4s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=18, min_samples_split=10, n_estimators=445; total time=  16.5s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=18, min_samples_split=10, n_estimators=445; total time=  16.4s
# [CV] END learning_rate=0.01, max_depth=5, max_features=log2, min_samples_leaf=15, min_samples_split=8, n_estimators=363; total time=   8.7s
# [CV] END learning_rate=0.01, max_depth=5, max_features=log2, min_samples_leaf=15, min_samples_split=8, n_estimators=363; total time=   8.8s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=18, min_samples_split=10, n_estimators=445; total time=  15.9s
# [CV] END learning_rate=0.1, max_depth=10, max_features=log2, min_samples_leaf=17, min_samples_split=5, n_estimators=149; total time=   4.7s
# [CV] END learning_rate=0.1, max_depth=10, max_features=log2, min_samples_leaf=17, min_samples_split=5, n_estimators=149; total time=   4.7s
# [CV] END learning_rate=0.1, max_depth=10, max_features=log2, min_samples_leaf=17, min_samples_split=5, n_estimators=149; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=5, max_features=log2, min_samples_leaf=15, min_samples_split=8, n_estimators=363; total time=   8.1s
# [CV] END learning_rate=0.1, max_depth=10, max_features=log2, min_samples_leaf=17, min_samples_split=5, n_estimators=149; total time=   4.8s
# [CV] END learning_rate=0.1, max_depth=10, max_features=log2, min_samples_leaf=17, min_samples_split=5, n_estimators=149; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=5, max_features=log2, min_samples_leaf=15, min_samples_split=8, n_estimators=363; total time=   8.0s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=359; total time=   6.8s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=359; total time=   6.7s
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=18, min_samples_split=13, n_estimators=261; total time=   4.8s
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=18, min_samples_split=13, n_estimators=261; total time=   4.8s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=359; total time=   6.7s
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=18, min_samples_split=13, n_estimators=261; total time=   4.8s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=359; total time=   6.7s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=359; total time=   6.7s
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=18, min_samples_split=13, n_estimators=261; total time=   4.8s
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=18, min_samples_split=13, n_estimators=261; total time=   4.8s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=14, min_samples_split=17, n_estimators=370; total time=   8.4s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=14, min_samples_split=17, n_estimators=370; total time=   8.4s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=14, min_samples_split=17, n_estimators=370; total time=   8.4s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=14, min_samples_split=17, n_estimators=370; total time=   8.5s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=14, min_samples_split=17, n_estimators=370; total time=   8.4s
# [CV] END learning_rate=0.2, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=17, n_estimators=336; total time=   8.4s
# [CV] END learning_rate=0.2, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=17, n_estimators=336; total time=   9.7s
# [CV] END learning_rate=0.2, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=17, n_estimators=336; total time=  10.5s
# [CV] END learning_rate=0.2, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=17, n_estimators=336; total time=  12.2s
# [CV] END learning_rate=0.2, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=17, n_estimators=336; total time=  12.9s
# [CV] END learning_rate=0.05, max_depth=10, max_features=sqrt, min_samples_leaf=13, min_samples_split=10, n_estimators=256; total time=  19.2s
# [CV] END learning_rate=0.05, max_depth=10, max_features=sqrt, min_samples_leaf=13, min_samples_split=10, n_estimators=256; total time=  19.3s
# [CV] END learning_rate=0.05, max_depth=10, max_features=sqrt, min_samples_leaf=13, min_samples_split=10, n_estimators=256; total time=  19.6s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=10, n_estimators=443; total time=  13.9s
# [CV] END learning_rate=0.05, max_depth=10, max_features=sqrt, min_samples_leaf=13, min_samples_split=10, n_estimators=256; total time=  19.4s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=10, n_estimators=443; total time=  13.4s
# [CV] END learning_rate=0.05, max_depth=10, max_features=sqrt, min_samples_leaf=13, min_samples_split=10, n_estimators=256; total time=  19.7s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=10, n_estimators=443; total time=  12.8s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=10, n_estimators=443; total time=  11.2s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=7, min_samples_split=10, n_estimators=443; total time=  11.0s
# [CV] END learning_rate=0.1, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=330; total time=  14.7s
# [CV] END learning_rate=0.1, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=330; total time=  14.5s
# [CV] END learning_rate=0.1, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=330; total time=  14.6s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=11, min_samples_split=18, n_estimators=491; total time=  26.7s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=11, min_samples_split=18, n_estimators=491; total time=  26.7s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=11, min_samples_split=18, n_estimators=491; total time=  26.9s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=11, min_samples_split=18, n_estimators=491; total time=  25.1s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=11, min_samples_split=18, n_estimators=491; total time=  25.2s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=427; total time=   6.7s
# [CV] END learning_rate=0.1, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=330; total time=  13.0s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=427; total time=   6.6s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=427; total time=   6.7s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=427; total time=   6.6s
# [CV] END learning_rate=0.2, max_depth=5, max_features=sqrt, min_samples_leaf=16, min_samples_split=6, n_estimators=198; total time=   5.9s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=427; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=330; total time=  13.0s
# [CV] END learning_rate=0.2, max_depth=5, max_features=sqrt, min_samples_leaf=16, min_samples_split=6, n_estimators=198; total time=   6.0s
# [CV] END learning_rate=0.2, max_depth=5, max_features=sqrt, min_samples_leaf=16, min_samples_split=6, n_estimators=198; total time=   6.0s
# [CV] END learning_rate=0.2, max_depth=5, max_features=sqrt, min_samples_leaf=16, min_samples_split=6, n_estimators=198; total time=   6.1s
# [CV] END learning_rate=0.2, max_depth=5, max_features=sqrt, min_samples_leaf=16, min_samples_split=6, n_estimators=198; total time=   6.0s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=326; total time=   8.2s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=326; total time=   7.9s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=326; total time=   8.1s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=326; total time=   8.0s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=326; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=104; total time=   8.4s
# [CV] END learning_rate=0.01, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=104; total time=   8.2s
# [CV] END learning_rate=0.01, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=104; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=104; total time=   8.4s
# [CV] END learning_rate=0.01, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=104; total time=   8.5s
# [CV] END learning_rate=0.01, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=14, n_estimators=278; total time=  15.3s
# [CV] END learning_rate=0.05, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=8, n_estimators=382; total time=  19.0s
# [CV] END learning_rate=0.05, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=8, n_estimators=382; total time=  18.6s
# [CV] END learning_rate=0.05, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=8, n_estimators=382; total time=  18.9s
# [CV] END learning_rate=0.05, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=8, n_estimators=382; total time=  19.3s
# [CV] END learning_rate=0.05, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=8, n_estimators=382; total time=  19.2s
# [CV] END learning_rate=0.01, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=14, n_estimators=278; total time=  15.8s
# [CV] END learning_rate=0.01, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=14, n_estimators=278; total time=  15.7s
# [CV] END learning_rate=0.01, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=14, n_estimators=278; total time=  15.4s
# [CV] END learning_rate=0.01, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=14, n_estimators
total time=   9.1s
# [CV] END learning_rate=0.05, max_depth=20, max_features=log2, min_samples_leaf=15, min_samples_split=3, n_estimators=226; total time=   8.8s
# [CV] END learning_rate=0.1, max_depth=20, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=459; total time=  12.8s
# [CV] END learning_rate=0.1, max_depth=20, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=459; total time=  13.0s
# [CV] END learning_rate=0.1, max_depth=5, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=492; total time=  11.4s
# [CV] END learning_rate=0.1, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=346; total time=   9.1s
# [CV] END learning_rate=0.1, max_depth=5, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=492; total time=  11.5s
# [CV] END learning_rate=0.1, max_depth=5, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=492; total time=  11.5s
# [CV] END learning_rate=0.1, max_depth=5, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=492; total time=  11.5s
# [CV] END learning_rate=0.1, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=346; total time=   9.0s
# [CV] END learning_rate=0.1, max_depth=5, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=492; total time=  11.4s
# [CV] END learning_rate=0.1, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=346; total time=   9.1s
# [CV] END learning_rate=0.1, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=346; total time=   9.1s
# [CV] END learning_rate=0.1, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=346; total time=   8.6s
# [CV] END learning_rate=0.2, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=499; total time=   7.4s
# [CV] END learning_rate=0.2, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=499; total time=   7.4s
# [CV] END learning_rate=0.05, max_depth=10, max_features=log2, min_samples_leaf=13, min_samples_split=8, n_estimators=412; total time=  15.3s
# [CV] END learning_rate=0.05, max_depth=10, max_features=log2, min_samples_leaf=13, min_samples_split=8, n_estimators=412; total time=  15.3s
# [CV] END learning_rate=0.05, max_depth=10, max_features=log2, min_samples_leaf=13, min_samples_split=8, n_estimators=412; total time=  15.5s
# [CV] END learning_rate=0.2, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=499; total time=   7.4s
# [CV] END learning_rate=0.2, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=499; total time=   7.4s
# [CV] END learning_rate=0.05, max_depth=10, max_features=log2, min_samples_leaf=13, min_samples_split=8, n_estimators=412; total time=  15.4s
# [CV] END learning_rate=0.05, max_depth=10, max_features=log2, min_samples_leaf=13, min_samples_split=8, n_estimators=412; total time=  15.3s
# [CV] END learning_rate=0.2, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=499; total time=   7.6s
# [CV] END learning_rate=0.2, max_depth=10, max_features=sqrt, min_samples_leaf=19, min_samples_split=18, n_estimators=279; total time=   8.7s
# [CV] END learning_rate=0.2, max_depth=10, max_features=sqrt, min_samples_leaf=19, min_samples_split=18, n_estimators=279; total time=   9.1s
# [CV] END learning_rate=0.2, max_depth=10, max_features=sqrt, min_samples_leaf=19, min_samples_split=18, n_estimators=279; total time=   8.6s
# [CV] END learning_rate=0.2, max_depth=10, max_features=sqrt, min_samples_leaf=19, min_samples_split=18, n_estimators=279; total time=   8.0s
# [CV] END learning_rate=0.2, max_depth=10, max_features=sqrt, min_samples_leaf=19, min_samples_split=18, n_estimators=279; total time=   8.1s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=11, min_samples_split=6, n_estimators=363; total time=  11.0s
# [CV] END learning_rate=0.05, max_depth=20, max_features=sqrt, min_samples_leaf=15, min_samples_split=3, n_estimators=421; total time=  22.1s
# [CV] END learning_rate=0.05, max_depth=20, max_features=sqrt, min_samples_leaf=15, min_samples_split=3, n_estimators=421; total time=  22.2s
# [CV] END learning_rate=0.05, max_depth=20, max_features=sqrt, min_samples_leaf=15, min_samples_split=3, n_estimators=421; total time=  22.0s
# [CV] END learning_rate=0.05, max_depth=20, max_features=sqrt, min_samples_leaf=15, min_samples_split=3, n_estimators=421; total time=  21.7s
# [CV] END learning_rate=0.05, max_depth=20, max_features=sqrt, min_samples_leaf=15, min_samples_split=3, n_estimators=421; total time=  22.5s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=11, min_samples_split=6, n_estimators=363; total time=  11.5s
# ...
# [CV] END learning_rate=0.01, max_depth=20, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=377; total time=  28.7s
# [CV] END learning_rate=0.01, max_depth=20, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=377; total time=  28.9s
# [CV] END learning_rate=0.01, max_depth=10, max_features=sqrt, min_samples_leaf=12, min_samples_split=17, n_estimators=185; total time=   9.4s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=16, n_estimators=193; total time=   3.0s
# [CV] END learning_rate=0.01, max_depth=10, max_features=sqrt, min_samples_leaf=12, min_samples_split=17, n_estimators=185; total time=   9.3s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=16, n_estimators=193; total time=   3.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=16, n_estimators=193; total time=   3.0s
# [CV] END learning_rate=0.01, max_depth=20, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=377; total time=  28.5s
# [CV] END learning_rate=0.01, max_depth=20, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=377; total time=  27.9s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=388; total time=  10.9s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=13, n_estimators=499; total time=  13.8s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=13, n_estimators=499; total time=  14.1s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=13, n_estimators=499; total time=  14.0s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=13, n_estimators=499; total time=  14.3s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=13, n_estimators=499; total time=  14.0s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=388; total time=  11.1s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=388; total time=  10.7s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=199; total time=   6.1s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=199; total time=   6.1s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=199; total time=   6.2s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=199; total time=   6.1s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=199; total time=   6.0s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=388; total time=   9.8s
# [CV] END learning_rate=0.05, max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=5, n_estimators=388; total time=   9.6s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=16, min_samples_split=3, n_estimators=483; total time=  16.9s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=16, min_samples_split=3, n_estimators=483; total time=  17.0s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=16, min_samples_split=3, n_estimators=483; total time=  17.1s
# [CV] END learning_rate=0.05, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=424; total time=  26.5s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=12, min_samples_split=19, n_estimators=262; total time=   6.0s
# [CV] END learning_rate=0.05, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=424; total time=  26.7s
# [CV] END learning_rate=0.05, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=424; total time=  26.5s
# [CV] END learning_rate=0.05, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=424; total time=  26.3s
# [CV] END learning_rate=0.05, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=424; total time=  26.9s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=12, min_samples_split=19, n_estimators=262; total time=   6.5s
# [CV] END learning_rate=0.2, max_depth=3, max_features=sqrt, min_samples_leaf=19, min_samples_split=12, n_estimators=200; total time=   4.1s
# [CV] END learning_rate=0.2, max_depth=3, max_features=sqrt, min_samples_leaf=19, min_samples_split=12, n_estimators=200; total time=   4.1s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=12, min_samples_split=19, n_estimators=262; total time=   6.5s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=12, min_samples_split=19, n_estimators=262; total time=   6.5s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=12, min_samples_split=19, n_estimators=262; total time=   6.6s
# [CV] END learning_rate=0.2, max_depth=3, max_features=sqrt, min_samples_leaf=19, min_samples_split=12, n_estimators=200; total time=   3.9s
# [CV] END learning_rate=0.2, max_depth=3, max_features=sqrt, min_samples_leaf=19, min_samples_split=12, n_estimators=200; total time=   3.9s
# [CV] END learning_rate=0.2, max_depth=3, max_features=sqrt, min_samples_leaf=19, min_samples_split=12, n_estimators=200; total time=   4.0s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=16, min_samples_split=3, n_estimators=483; total time=  17.3s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=16, min_samples_split=3, n_estimators=483; total time=  17.7s
# [CV] END learning_rate=0.2, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=429; total time=   7.4s
# [CV] END learning_rate=0.2, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=429; total time=   7.4s
# [CV] END learning_rate=0.2, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=429; total time=   7.5s
# [CV] END learning_rate=0.2, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=429; total time=   7.3s
# [CV] END learning_rate=0.2, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=429; total time=   7.4s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=19, n_estimators=134; total time=   4.0s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=19, n_estimators=134; total time=   3.9s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=19, n_estimators=134; total time=   3.8s
# [CV] END learning_rate=0.1, max_depth=20, max_features=sqrt, min_samples_leaf=13, min_samples_split=13, n_estimators=194; total time=  11.3s
# [CV] END learning_rate=0.1, max_depth=20, max_features=sqrt, min_samples_leaf=13, min_samples_split=13, n_estimators=194; total time=  11.0s
# [CV] END learning_rate=0.1, max_depth=20, max_features=sqrt, min_samples_leaf=13, min_samples_split=13, n_estimators=194; total time=  11.1s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=19, n_estimators=134; total time=   4.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=189; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=189; total time=   3.1s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=19, n_estimators=134; total time=   4.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=189; total time=   3.0s
# [CV] END learning_rate=0.1, max_depth=20, max_features=sqrt, min_samples_leaf=13, min_samples_split=13, n_estimators=194; total time=  11.1s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=189; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=20, max_features=sqrt, min_samples_leaf=13, min_samples_split=13, n_estimators=194; total time=  10.8s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=189; total time=   2.9s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=13, min_samples_split=12, n_estimators=475; total time=   8.4s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=13, min_samples_split=12, n_estimators=475; total time=   8.6s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=295; total time=  10.8s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=295; total time=  10.7s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=13, min_samples_split=12, n_estimators=475; total time=   8.6s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=295; total time=  10.8s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=295; total time=  10.7s
# [CV] END learning_rate=0.05, max_depth=5, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=295; total time=  10.8s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=13, min_samples_split=12, n_estimators=475; total time=   7.5s
# [CV] END learning_rate=0.05, max_depth=3, max_features=log2, min_samples_leaf=13, min_samples_split=12, n_estimators=475; total time=   7.4s
# [CV] END learning_rate=0.2, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=11, n_estimators=456; total time=   9.4s
# [CV] END learning_rate=0.2, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=11, n_estimators=456; total time=   9.3s
# [CV] END learning_rate=0.2, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=11, n_estimators=456; total time=   9.4s
# [CV] END learning_rate=0.2, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=11, n_estimators=456; total time=   9.4s
# [CV] END learning_rate=0.2, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=11, n_estimators=456; total time=   9.4s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=198; total time=  12.1s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=17, min_samples_split=8, n_estimators=195; total time=   6.9s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=17, min_samples_split=8, n_estimators=195; total time=   6.7s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=17, min_samples_split=8, n_estimators=195; total time=   6.7s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=198; total time=  12.2s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=198; total time=  12.2s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=17, min_samples_split=8, n_estimators=195; total time=   6.6s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=198; total time=  12.1s
# [CV] END learning_rate=0.01, max_depth=20, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=198; total time=  12.2s
# [CV] END learning_rate=0.2, max_depth=20, max_features=log2, min_samples_leaf=17, min_samples_split=8, n_estimators=195; total time=   6.8s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=13, n_estimators=468; total time=   7.1s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=13, n_estimators=468; total time=   7.1s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=13, n_estimators=468; total time=   7.6s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=13, n_estimators=468; total time=   7.7s
# [CV] END learning_rate=0.2, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=13, n_estimators=468; total time=   7.8s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=385; total time=   9.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=385; total time=   9.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, min_samples_leaf=16, min_samples_split=14, n_estimators=286; total time=   5.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, min_samples_leaf=16, min_samples_split=14, n_estimators=286; total time=   5.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, min_samples_leaf=16, min_samples_split=14, n_estimators=286; total time=   4.8s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=385; total time=   9.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=385; total time=   9.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=385; total time=   9.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, min_samples_leaf=12, min_samples_split=10, n_estimators=175; total time=   2.8s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, min_samples_leaf=12, min_samples_split=10, n_estimators=175; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, min_samples_leaf=12, min_samples_split=10, n_estimators=175; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, min_samples_leaf=12, min_samples_split=10, n_estimators=175; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, min_samples_leaf=16, min_samples_split=14, n_estimators=286; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, min_samples_leaf=16, min_samples_split=14, n_estimators=286; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, min_samples_leaf=12, min_samples_split=10, n_estimators=175; total time=   2.5s
# [CV] END learning_rate=0.01, max_depth=10, max_features=log2, min_samples_leaf=14, min_samples_split=16, n_estimators=243; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=10, max_features=log2, min_samples_leaf=14, min_samples_split=16, n_estimators=243; total time=   8.2s
# [CV] END learning_rate=0.01, max_depth=10, max_features=log2, min_samples_leaf=14, min_samples_split=16, n_estimators=243; total time=   7.8s
# [CV] END learning_rate=0.01, max_depth=10, max_features=log2, min_samples_leaf=14, min_samples_split=16, n_estimators=243; total time=   7.7s
# [CV] END learning_rate=0.01, max_depth=10, max_features=log2, min_samples_leaf=14, min_samples_split=16, n_estimators=243; total time=   7.7s

# %%
# Train the model with the best parameters
best_model_gb = GradientBoostingClassifier(**best_params, random_state=42)
best_model_gb.fit(X_train, y_train)

# Make predictions
best_predictions = best_model_gb.predict(X_test)

# Evaluate the model
classification_report_best = classification_report(y_test, best_predictions)

# Display the results
print("Best Parameters:", best_params)
print("\nClassification Report:\n", classification_report_best)

# Perform cross-validation
cv_scores = cross_val_score(best_model_gb, X_resampled, y_resampled, cv=stratified_kfold, scoring='f1_weighted')
print("\nCross-Validation F1 Weighted Scores:", cv_scores)
print("Mean CV F1 Weighted Score:", cv_scores.mean())
# Out:
# Best Parameters: {'learning_rate': 0.01, 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 3, 'min_samples_split': 18, 'n_estimators': 198}
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          CVP       0.57      0.67      0.62        36
#          EVP       0.56      0.50      0.53        30
#          FDP       0.64      0.55      0.59        38
#          GLP       0.67      0.53      0.59        34
#          GPS       0.42      0.37      0.39        30
#           SP       0.60      0.72      0.66        29
#          SVP       0.41      0.52      0.46        27
#
#     accuracy                           0.55       224
#    macro avg       0.55      0.55      0.55       224
# weighted avg       0.56      0.55      0.55       224
#
#
# Cross-Validation F1 Weighted Scores: [0.57171306 0.56574771 0.54226914 0.55185958 0.52899797]
# Mean CV F1 Weighted Score: 0.552117492067031

# %%
print("Final features used by the model:", final_feature_names)
# Out:
# Final features used by the model: ['sex', 'age', 'educ', 'income', 'religion', 'sg1', 'sg9', 'sc1', 'sc7b', 'pi1', 'pm3', 'vp1', 'pid1', 'sex^2', 'sex age', 'sex educ', 'sex income', 'sex religion', 'sex sg1', 'sex sg9', 'sex sc1', 'sex sc7b', 'sex pi1', 'sex pm3', 'sex vp1', 'sex pid1', 'age^2', 'age educ', 'age income', 'age religion', 'age sg1', 'age sg9', 'age sc1', 'age sc7b', 'age pi1', 'age pm3', 'age vp1', 'age pid1', 'educ^2', 'educ income', 'educ religion', 'educ sg1', 'educ sg9', 'educ sc1', 'educ sc7b', 'educ pi1', 'educ pm3', 'educ vp1', 'educ pid1', 'income^2', 'income religion', 'income sg1', 'income sg9', 'income sc1', 'income sc7b', 'income pi1', 'income pm3', 'income vp1', 'income pid1', 'religion^2', 'religion sg1', 'religion sg9', 'religion sc1', 'religion sc7b', 'religion pi1', 'religion pm3', 'religion vp1', 'religion pid1', 'sg1^2', 'sg1 sg9', 'sg1 sc1', 'sg1 sc7b', 'sg1 pi1', 'sg1 pm3', 'sg1 vp1', 'sg1 pid1', 'sg9^2', 'sg9 sc1', 'sg9 sc7b', 'sg9 pi1', 'sg9 pm3', 'sg9 vp1', 'sg9 pid1', 'sc1^2', 'sc1 sc7b', 'sc1 pi1', 'sc1 pm3', 'sc1 vp1', 'sc1 pid1', 'sc7b^2', 'sc7b pi1', 'sc7b pm3', 'sc7b vp1', 'sc7b pid1', 'pi1^2', 'pi1 pm3', 'pi1 vp1', 'pi1 pid1', 'pm3^2', 'pm3 vp1', 'pm3 pid1', 'vp1^2', 'vp1 pid1', 'pid1^2', 'age_income_interaction']

# %%
# Save the model and feature names
joblib.dump(best_model_gb, '../data/models/best_gb_model.pkl')
joblib.dump(final_feature_names, '../data/models/feature_names.pkl')
# Out:
# ['../data/models/feature_names.pkl']
