# %% [markdown]
# # Data

# %% [markdown]
# ## Necessary packages and libraries

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib

# %% [markdown]
# ## Load Selects cumulative data

# %%
# Define the file path
file_path = '../data/selects_cumulative_1971-2019.dta'

# Load the Stata file
data = pd.read_stata(file_path)

# %%
# Save the dataframe to a CSV file
csv_file_path = "../data/selects_cumulative_1971-2019.csv"
data.to_csv(csv_file_path, index=False)

print(f"Data saved to {csv_file_path}")
# Out:
# Data saved to ../data/selects_cumulative_1971-2019.csv

# %%
data.head()
# Out:
#    year  userid  useridpy     sex   age maritals                  educ  \
# 0  1971       1       3.0    male  33.0  married        primary school
# 1  1971       2       5.0    male  56.0  married  compulsory education
# 2  1971       3       6.0    male  49.0  married        primary school
# 3  1971       4       9.0  female  60.0  married        primary school
# 4  1971       5      10.0  female  39.0  married  compulsory education
#
#   income_sfr income income_hh  ... intinf2 intinf3 intinf4       intinf5  \
# 0        NaN    NaN       NaN  ...     2.0  1972.0    70.0  wife/husband
# 1        NaN    NaN       NaN  ...     6.0  1972.0    50.0        no one
# 2        NaN    NaN       NaN  ...     2.0  1972.0    60.0        no one
# 3        NaN    NaN       NaN  ...     6.0  1972.0    55.0        no one
# 4        NaN    NaN       NaN  ...     2.0  1972.0    65.0  wife/husband
#
#     intinf6         intinf7 weightc weightst weightp weighttot
# 0     never        0.666667     1.0    0.936  1.0000  0.936000
# 1       NaN        0.666667     1.0    0.936  1.0000  0.936000
# 2       NaN  not interested     1.0    1.000  1.0000  1.000000
# 3       NaN        0.666667     1.0    1.099  1.0000  1.099000
# 4  0.666667        0.333333     1.0    0.936  1.3648  1.277453
#
# [5 rows x 347 columns]

# %% [markdown]
# ## Selecting chosen variables

# %%
# Loading original data before subsetting
subset_source = pd.read_csv("../data/selects_cumulative_1971-2019.csv")
# Out:
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/3116790635.py:2: DtypeWarning: Columns (9,10,11,17,19,20,23,24,25,27,31,33,34,36,37,38,43,44,45,46,50,51,52,55,56,57,58,59,63,64,65,66,67,68,69,73,74,78,79,80,83,85,86,87,92,93,94,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,114,115,116,117,118,119,120,121,122,123,124,125,126,128,129,130,131,132,133,134,135,136,137,138,139,140,141,143,144,145,146,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,192,193,194,195,196,197,198,199,200,201,202,208,209,210,211,212,213,214,215,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,271,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,340,341,342) have mixed types. Specify dtype option on import or set low_memory=False.
#   subset_source = pd.read_csv("../data/selects_cumulative_1971-2019.csv")

# %%
# Create a subset with selected columns
selected_columns = ['year', 'userid', 'sex', 'age', 'educ', 'income',
                    'religion','sg1', 'sg9', 'sc1', 'sc7a', 'sc7b',
                    'pi1', 'lr1', 'pm3',
                    'vp1', 'vdn1b', 'pid1', 'pid2b', 'trust1',
                    'weighttot']  
subset = subset_source.loc[:, selected_columns]
subset.head()
# Out:
#    year  userid     sex   age                  educ income religion  \
# 0  1971       1    male  33.0        primary school    NaN     cath
# 1  1971       2    male  56.0  compulsory education    NaN    other
# 2  1971       3    male  49.0        primary school    NaN     cath
# 3  1971       4  female  60.0        primary school    NaN     prot
# 4  1971       5  female  39.0  compulsory education    NaN     prot
#
#              sg1  sg9                    sc1  ...  \
# 0  French spoken  NaN  in training/formation  ...
# 1  French spoken  NaN              full-time  ...
# 2  French spoken  NaN              full-time  ...
# 3  French spoken  NaN           in household  ...
# 4  French spoken  NaN     without profession  ...
#
#                                 sc7b                    pi1  lr1  \
# 0            service class employees  rather not interested  NaN
# 1                other self-employed  rather not interested  NaN
# 2  semiskilled and unskilled workers  rather not interested  NaN
# 3                                NaN  not interested at all  NaN
# 4            service class employees  rather not interested  NaN
#
#              pm3  vp1    vdn1b pid1                    pid2b  \
# 0    materialist  yes      NaN  yes                  sps/pss
# 1  mixed postmat  yes      NaN  yes                  sps/pss
# 2      mixed mat  NaN      NaN   no  no party identification
# 3      mixed mat   no      NaN   no  no party identification
# 4      mixed mat  yes  fdp/prd   no  no party identification
#
#                trust1 weighttot
# 0                 NaN  0.936000
# 1   6.666666507720947  0.936000
# 2   6.666666507720947  1.000000
# 3                 NaN  1.099000
# 4  3.3333332538604736  1.277453
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Preprocessing data

# %%
# Replace "NaN" with "0" for both numeric and categorical data
subset_clean = subset.fillna(0)

# Further select most important variables
column_drop = ["year", "userid", "lr1", "pid2b", "sc7a", "weighttot", "trust1"]
subset_clean = subset_clean.drop(column_drop, axis=1)

subset_clean.head()
# Out:
#       sex   age                  educ income religion            sg1 sg9  \
# 0    male  33.0        primary school      0     cath  French spoken   0
# 1    male  56.0  compulsory education      0    other  French spoken   0
# 2    male  49.0        primary school      0     cath  French spoken   0
# 3  female  60.0        primary school      0     prot  French spoken   0
# 4  female  39.0  compulsory education      0     prot  French spoken   0
#
#                      sc1                               sc7b  \
# 0  in training/formation            service class employees
# 1              full-time                other self-employed
# 2              full-time  semiskilled and unskilled workers
# 3           in household                                  0
# 4     without profession            service class employees
#
#                      pi1            pm3  vp1    vdn1b pid1
# 0  rather not interested    materialist  yes        0  yes
# 1  rather not interested  mixed postmat  yes        0  yes
# 2  rather not interested      mixed mat    0        0   no
# 3  not interested at all      mixed mat   no        0   no
# 4  rather not interested      mixed mat  yes  fdp/prd   no

# %%
# Dictionary to rename categories
category_rename_mapping = {
    0: 'unknown',  # Example for numeric 0
    'GLP/Vert\'libéraux': "GLP",
    'bdp': 'BDP',
    'centre parties': 'Centre Parties',
    'csp/pcs': 'CSP',
    'cvp/pdc': 'CVP',
    'edu/udf': 'EDU',
    'evp/pep': 'EVP',
    'fdp/prd': 'FDP',
    'fga/avf': 'FGA',
    'fps/psl': 'FPS',
    'gps/pes': 'GPS',
    'ldu/adi': 'LdU',
    'left parties': 'Left Parties',
    'lega': 'Lega',
    'lps/pls': 'LPS',
    'mcg': 'MCG',
    'other comments': 'Other Comments',
    'other parties': 'Other Parties',
    'pda/pdt': 'PdA',
    'poch': 'POCH',
    'psa (psu)': 'PSA',
    'rep. (& vigil.)': 'Rep',
    'right parties': 'Right Parties',
    'sd/ds': 'SD',
    'sol.': 'Sol',
    'sps/pss': 'SP',
    'svp/udc': 'SVP',
    'voted blank': 'Voted Blank'
}

# %%
# Convert vdn1b to a categorical text variable
subset_clean['vdn1b'] = subset_clean['vdn1b'].astype('category')

# Rename categories
subset_clean['vdn1b'] = subset_clean['vdn1b'].cat.rename_categories(category_rename_mapping)

# Verify the renaming
print("Renamed categories:", subset_clean['vdn1b'].cat.categories)

# Change LPS to FDP
subset_clean['vdn1b'] = subset_clean['vdn1b'].replace({'LPS': 'FDP'})
# Out:
# Renamed categories: Index(['unknown', 'GLP', 'BDP', 'Centre Parties', 'CSP', 'CVP', 'EDU', 'EVP',
#        'FDP', 'FGA', 'FPS', 'GPS', 'LdU', 'Left Parties', 'Lega', 'LPS', 'MCG',
#        'Other Comments', 'Other Parties', 'PdA', 'POCH', 'PSA', 'Rep',
#        'Right Parties', 'SD', 'Sol', 'SP', 'SVP', 'Voted Blank'],
#       dtype='object')
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/2244865309.py:11: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   subset_clean['vdn1b'] = subset_clean['vdn1b'].replace({'LPS': 'FDP'})

# %%
subset_clean['vdn1b'].unique()
# Out:
# ['unknown', 'FDP', 'PdA', 'SP', 'Other Parties', ..., 'PSA', 'Centre Parties', 'BDP', 'GLP', 'MCG']
# Length: 28
# Categories (28, object): ['unknown', 'GLP', 'BDP', 'Centre Parties', ..., 'Sol', 'SP', 'SVP', 'Voted Blank']

# %%
# Select most important existing parties
subset_selected_parties = subset_clean[subset_clean['vdn1b'].isin(['FDP','CVP','SP','SVP','EVP',
                                                        'GPS', 'GLP'])]

subset_selected_parties
# Out:
#           sex   age                  educ               income religion  \
# 4      female  39.0  compulsory education                    0     prot
# 9      female  43.0  compulsory education                    0    other
# 12     female  33.0        primary school                    0     cath
# 23       male  78.0        primary school                    0     prot
# 27       male  76.0        primary school                    0     cath
# ...       ...   ...                   ...                  ...      ...
# 43660    male  28.0  compulsory education           low income     none
# 43661    male  43.0    vocational college   rather high income     none
# 43663  female  52.0  vocational education    rather low income     none
# 43665  female  42.0            university   rather high income     prot
# 43666  female  46.0            university        medium income     cath
#
#                  sg1    sg9                 sc1  \
# 4      French spoken      0  without profession
# 9      French spoken      0           full-time
# 12     French spoken      0           full-time
# 23     French spoken      0             retired
# 27     French spoken      0             retired
# ...              ...    ...                 ...
# 43660  French spoken  urban               other
# 43661  German spoken  rural           part-time
# 43663  German spoken  rural           part-time
# 43665  German spoken  urban           part-time
# 43666  French spoken  urban          unemployed
#
#                                     sc7b                    pi1          pm3  \
# 4                service class employees  rather not interested    mixed mat
# 9                                 others  not interested at all  materialist
# 12     semiskilled and unskilled workers  not interested at all    mixed mat
# 23               skilled workers/foremen  not interested at all    mixed mat
# 27               skilled workers/foremen  not interested at all  materialist
# ...                                  ...                    ...          ...
# 43660                                  0        very interested            0
# 43661                                  0      rather interested            0
# 43663                                  0      rather interested            0
# 43665                                  0      rather interested            0
# 43666                                  0      rather interested            0
#
#        vp1 vdn1b pid1
# 4      yes   FDP   no
# 9      yes    SP   no
# 12     yes    SP  yes
# 23     yes    SP   no
# 27     yes    SP  yes
# ...    ...   ...  ...
# 43660  yes   GLP   no
# 43661  yes   FDP   no
# 43663  yes    SP   no
# 43665  yes   GLP  yes
# 43666  yes    SP  yes
#
# [23842 rows x 14 columns]

# %%
# Identify categorical columns
categorical_cols = subset_selected_parties.select_dtypes(include=['object']).columns
categorical_cols = [col for col in categorical_cols if col != 'vdn1b']

# Encode categorical columns using LabelEncoder
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    subset_selected_parties[col] = le.fit_transform(subset_selected_parties[col].astype(str))
    label_encoders[col] = le
    
    # Print encoding mapping for each column
    print(f"Encoding mapping for {col}:")
    print(dict(zip(le.classes_, le.transform(le.classes_))))
    print()  # Add a blank line for readability

# Save the encoders for later use
joblib.dump(label_encoders, '../data/models/label_encoders.pkl')

# Verify the conversion of vdn1b
print("vdn1b dtype:", subset_selected_parties['vdn1b'].dtype)  # Should show 'category'
# Out:
# Encoding mapping for sex:
# {'female': np.int64(0), 'male': np.int64(1)}
#
# Encoding mapping for educ:
# {'0': np.int64(0), 'basic vocational training': np.int64(1), 'compulsory education': np.int64(2), 'diploma school': np.int64(3), 'high school': np.int64(4), 'higher vocational training': np.int64(5), 'primary school': np.int64(6), 'university': np.int64(7), 'vocational college': np.int64(8), 'vocational education': np.int64(9)}
#
# Encoding mapping for income:
# {' rather high income': np.int64(0), ' rather low income': np.int64(1), '0': np.int64(2), 'high income': np.int64(3), 'low income': np.int64(4), 'medium income': np.int64(5)}
#
# Encoding mapping for religion:
# {'0': np.int64(0), 'cath': np.int64(1), 'none': np.int64(2), 'other': np.int64(3), 'prot': np.int64(4)}
#
# Encoding mapping for sg1:
# {'0': np.int64(0), 'French spoken': np.int64(1), 'German spoken': np.int64(2), 'Italian spoken': np.int64(3)}
#
# Encoding mapping for sg9:
# {'0': np.int64(0), 'rural': np.int64(1), 'urban': np.int64(2)}
#
# Encoding mapping for sc1:
# {'0': np.int64(0), 'disabled': np.int64(1), 'full-time': np.int64(2), 'in family business': np.int64(3), 'in household': np.int64(4), 'in training/formation': np.int64(5), 'other': np.int64(6), 'part-time': np.int64(7), 'retired': np.int64(8), 'unemployed': np.int64(9), 'without profession': np.int64(10)}
#
# Encoding mapping for sc7b:
# {'0': np.int64(0), 'farmers': np.int64(1), 'other self-employed': np.int64(2), 'others': np.int64(3), 'routine non-manual workers': np.int64(4), 'semiskilled and unskilled workers': np.int64(5), 'service class employees': np.int64(6), 'skilled workers/foremen': np.int64(7)}
#
# Encoding mapping for pi1:
# {'0': np.int64(0), 'not interested at all': np.int64(1), 'rather interested': np.int64(2), 'rather not interested': np.int64(3), 'very interested': np.int64(4)}
#
# Encoding mapping for pm3:
# {'0': np.int64(0), 'materialist': np.int64(1), 'mixed mat': np.int64(2), 'mixed postmat': np.int64(3), 'post-materialist': np.int64(4)}
#
# Encoding mapping for vp1:
# {'0': np.int64(0), 'yes': np.int64(1)}
#
# Encoding mapping for pid1:
# {'0': np.int64(0), 'no': np.int64(1), 'yes': np.int64(2)}
#
# vdn1b dtype: category
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/1151502081.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_selected_parties[col] = le.fit_transform(subset_selected_parties[col].astype(str))
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/1151502081.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_selected_parties[col] = le.fit_transform(subset_selected_parties[col].astype(str))
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/1151502081.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_selected_parties[col] = le.fit_transform(subset_selected_parties[col].astype(str))
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/1151502081.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_selected_parties[col] = le.fit_transform(subset_selected_parties[col].astype(str))
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/1151502081.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_selected_parties[col] = le.fit_transform(subset_selected_parties[col].astype(str))
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/1151502081.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_selected_parties[col] = le.fit_transform(subset_selected_parties[col].astype(str))
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/1151502081.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_selected_parties[col] = le.fit_transform(subset_selected_parties[col].astype(str))
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/1151502081.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_selected_parties[col] = le.fit_transform(subset_selected_parties[col].astype(str))
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/1151502081.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_selected_parties[col] = le.fit_transform(subset_selected_parties[col].astype(str))
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/1151502081.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_selected_parties[col] = le.fit_transform(subset_selected_parties[col].astype(str))
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/1151502081.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_selected_parties[col] = le.fit_transform(subset_selected_parties[col].astype(str))
# /var/folders/h8/ktkbvtz97k79p3_2tbjkwg9r0000gp/T/ipykernel_12494/1151502081.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_selected_parties[col] = le.fit_transform(subset_selected_parties[col].astype(str))

# %% [markdown]
# ## Save subset with 8 most important parties

# %%
# save subset data
subset_selected_parties.to_csv('../data/subset_selected_parties_model.csv', index=False)
